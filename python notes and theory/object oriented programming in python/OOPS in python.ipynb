# %%
class Person:
    age=""
    weight=""
    height=""
    name="" 
    def runSpeed(self,age,weight,height):
        return((age*height)/weight)
    
amit= Person()
amit.age=45
amit.weight=56.7
amit.height=6.1
amit.name="Amit Kumar"
speed= amit.runSpeed(amit.age,amit.weight,amit.height)
print("Amit ",speed)

kiran= Person()
kiran.age=48
kiran.weight=26.7
kiran.height=4.1
kiran.name="Kiran Raja"
kspeed= kiran.runSpeed(kiran.age,kiran.weight,kiran.height)
print("Kiran ",kspeed)
# Out:
# Amit  4.841269841269841
# Kiran  7.370786516853932

# %%
class Person:
    age=""
    weight=""
    height=""
    name="" 
    def __init__(self,age,weight,height):
        self.age  = age
        self.weight = weight
        self.height= height
    def runSpeed(self):
        return((self.age*self.height)/self.weight)
    
amit= Person(45,56.7,6.1)
speed= amit.runSpeed()
print("Amit ",speed)
kiran= Person(48,26.7,4.1)
kspeed= kiran.runSpeed()
print("Kiran ",kspeed)
# Out:
# Amit  4.841269841269841
# Kiran  7.370786516853932

# %%
class Person:
    age=""
    weight=""
    height=""
    def runSpeed(self,age,weight,height):
        return((age*height)/weight)
if __name__== "__main__":
    kumar =  Person()
    kumar.age=34
    kumar.weight=45.3
    kumar.height=54.2
    speed= kumar.runSpeed(kumar.age,kumar.weight,kumar.height)
    print("Amit Running Speed",speed)
    kumar1 =  Person()
    kumar1.age=32
    kumar1.weight=42.3
    kumar1.height=51.2
    speed1= kumar1.runSpeed(kumar1.age,kumar1.weight,kumar1.height)
    print("Kiran Running Speed",speed1)
# Out:
# Amit Running Speed 40.679911699779254
# Kiran Running Speed 38.73286052009457

# %%
class Person:
    age=""
    weight=""
    height=""
    def __init__(self,a,w,h): #Method (Initializer)
        self.age = a
        self.weight = w
        self.height = h
        
    def runSpeed(self,age,weight,height):
        return((age*height)/weight)
if __name__== "__main__":
    kumar =  Person(34,45.3,54.2)
    speed= kumar.runSpeed(kumar.age,kumar.weight,kumar.height)
    print("Speed",speed)
    kumar1 =  Person(32,42.3,51.2)
    speed1= kumar1.runSpeed(kumar1.age,kumar1.weight,kumar1.height)
    print("Speed",speed1)
    print(kumar.__class__)
# Out:
# Speed 40.679911699779254
# Speed 38.73286052009457
# <class '__main__.Person'>

# %%
class Person:
    age=""
    weight=""
    height=""
    def __init__(self,age,weight,height):
        self.age = age
        self.weight = weight
        self.height = height
        
    def runSpeed(self,age,weight,height):
        return((age*height)/weight)
if __name__== "__main__":
    kumar =  Person(34,45.3,54.2)
    speed= kumar.runSpeed(kumar.age,kumar.weight,kumar.height)
    print("Speed",speed)
    kumar1 =  Person(32,42.3,51.2)
    speed1= kumar1.runSpeed(kumar1.age,kumar1.weight,kumar1.height)
    print("Speed",speed1)
# Out:
# Speed 40.679911699779254
# Speed 38.73286052009457

# %%
class Student:
    def __init__(self):
        print("Defaut MEthod initilizer")
s = Student()
# Out:
# Defaut MEthod initilizer

# %%
class Student:
    def __init__(self,a):
        print("Defaut MEthod initilizer",a)
s = Student(10)
# Out:
# Defaut MEthod initilizer 10

# %%
# Python code has an error because of multiple __init__ methods 
# in the Student class
class Student:
    def __init__(self):
        print("Defaut MEthod initilizer")
    def __init__(self,a,b):
        print(a+b)
s = Student() #Error: missing required arguments
s1 = Student(3,4) # fine
# n Python, a class cannot have multiple __init__ methods
# because the second __init__ method overwrites the first one.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14560\2167653788.py in <module>
#       6     def __init__(self,a,b):
#       7         print(a+b)
# ----> 8 s = Student() #Error: missing required arguments
#       9 s1 = Student(3,4) # fine
#      10 # n Python, a class cannot have multiple __init__ methods
#
# TypeError: __init__() missing 2 required positional arguments: 'a' and 'b'

# %% [markdown]
# # USING MULTIPLE INIT IN A PROGRAM:

# %% [markdown]
# # Solution 1: Use Default Arguments
# - A simple way to fix this issue is by using default values for the parameters:

# %%
class Student:
    def __init__(self, a=0, b=0):
        if a == 0 and b == 0:
            print("Default Method Initializer")
        else:
            print(a + b)

s1 = Student()      # Prints: Default Method Initializer
s1 = Student(3, 4) # Prints: 7
# Out:
# Default Method Initializer
# 7

# %% [markdown]
# # Solution 2: Use *args to Handle Multiple Cases
# - You can use *args to handle variable-length arguments:

# %%
class Student:
    def __init__(self, *args):
        if len(args) == 0:
            print("Default Method Initializer")
        elif len(args) == 2:
            print(args[0] + args[1])
        else:
            print("Invalid number of arguments")

s = Student()      # Prints: Default Method Initializer
s1 = Student(3, 4) # Prints: 7
s2 = Student(5)    # Prints: Invalid number of arguments
# Out:
# Default Method Initializer
# 7
# Invalid number of arguments

# %% [markdown]
# # Decorator:  change the exiting function
# <href>https://www.youtube.com/watch?v=rq8cL2XMM5M</href>

# %%
def div(a,b):
    print(a/b)
div(10,2)

def div(a,b):
    print(a/b)
div(2,10)
# Out:
# 5.0
# 0.2

# %%
def div(a,b):
    print(a/b)

def smart_div(func): # smart_div is a decorator function. It takes a function func as an argument.
    def inner(a,b):
        if(a<b):
            a,b=b,a
        return func(a,b)
    return inner
di  = smart_div(div)
di(2,10)
di(10,2)
# Out:
# 5.0
# 5.0

# %% [markdown]
# # Solution 3: Use Method Overloading via @classmethod
# - Python does not support method overloading like Java or C++, but you can achieve similar behavior using class methods:
# - Python does not support multiple constructors (__init__ methods). Using a @classmethod like with_values
# - Decorators allow us to modify or extend the behavior of a function without changing its actual code.

# %%
# Class Decorator (@classmethod)
class Student:
    def __init__(self):
        print("Default Method Initializer")
    #@classmethod decorator makes with_values a class method, meaning it does not require an instance (self)
    # but instead works with the class itself (cls).
    @classmethod
    def with_values(cls, a, b): 
        #cls refers to the Student class
        #Calls cls(), which means Student(), triggering the __init__ method
        #obj = Student()
        obj = cls() # Create a default using the default constructor (__init__)
        print(a + b)
        return obj
s = Student()                # Prints: Default Method Initializer
s1 = Student.with_values(3,4)# Prints: Default Method Initializer, then 7
# Out:
# Default Method Initializer
# Default Method Initializer
# 7

# %%
class Example:
    @classmethod
    def overloaded_method(cls, a=None, b=None):
        if a is not None and b is not None:
            return f"Two parameters: {a}, {b}"
        elif a is not None:
            return f"One parameter: {a}"
        else:
            return "No parameters"

print(Example.overloaded_method())       # No parameters
print(Example.overloaded_method(10))     # One parameter: 10
print(Example.overloaded_method(10, 20)) # Two parameters: 10, 20
# Out:
# No parameters
# One parameter: 10
# Two parameters: 10, 20

# %% [markdown]
# # Example: Method Overloading via @classmethod

# %%
#The @classmethod decorator allows us to define a method that belongs to the class rather than an instance.
class Calculator:
    def __init__(self, value=0):
        self.value = value

    @classmethod
    def add(cls, a, b=None):
        """Overloaded method to add one or two numbers."""
        if b is None:
            return cls(a)  # If one argument, return instance with value set
        return cls(a + b)  # If two arguments, return instance with sum

    def get_value(self):
        return self.value

# Using the overloaded method
calc1 = Calculator.add(5)  # Single argument
print(calc1.get_value())  # Output: 5

calc2 = Calculator.add(3, 7)  # Two arguments
print(calc2.get_value())  # Output: 10
# Out:
# 5
# 10

# %% [markdown]
# # Property Decorator (@property)
# - A custom getter and setter using @property.

# %%
class Circle:
    def __init__(self, radius):
        self._radius = radius # self._radius (with an underscore) is used as a private attribute to store the radius

    @property  # The @property decorator makes radius a getter method. 
    def radius(self):  # This allows us to access radius as an attribute instead of calling a method
        return self._radius  # # Instead of c.radius()

    @radius.setter  # The @radius.setter decorator allows controlled modification of radius.
    def radius(self, value):
        if value < 0:
            raise ValueError("Radius cannot be negative!")
        self._radius = value

    @property  # area is defined as a property, so we can call c.area without parentheses.
    def area(self):
        return 3.14159 * self._radius ** 2

c = Circle(-5)
print(c.area)  # 78.53975
c.radius = 10
print(c.area)  # 314.159
# Out:
# 78.53975
# 314.159

# %% [markdown]
# # Basic Function Decorator

# %%
import time # The time module provides various functions to handle time-related operation

def timing_decorator(func):  # Defining the Decorator (timing_decorator)
    def wrapper(*args, **kwargs):
        start_time = time.time() # time.time() to get the current time in seconds (Unix timestamp)
        result = func(*args, **kwargs) # # Execute the original function
        end_time = time.time() # # Capture end time
        print(f"Executed {func.__name__} in {end_time - start_time:.4f} seconds")
        return result
    return wrapper

# Applying the Decorator (@timing_decorator)
# slow_function = timing_decorator(slow_function)
#This means slow_function is wrapped inside wrapper, which measures its execution time.
@timing_decorator    
def slow_function():
    time.sleep(2)  # # Simulates a delay of 2 seconds
    print("Function executed")

slow_function()
# When called, slow_function is actually wrapper(), which
# Starts the timer.
# Runs slow_function(), which sleeps for 2 seconds and prints "Function executed"
# Stops the timer.
# Prints the execution time.
# Out:
# Function executed
# Executed slow_function in 2.0102 seconds

# %% [markdown]
# #  Static Method Decorator (@staticmethod)
# - A static method that doesn’t depend on instance or class variables.

# %%
class MathUtils:
    c=10
    @staticmethod
    def add(a, b):
        #print(MathUtils.c)
        return a + b

print(MathUtils.add(5, 10))  # Output: 15

m  = MathUtils()
print(m.add(3,4)); # MathUtils.add(5, 10)
# Out:
# 15
# 7

# %%
# Display Class Attribute and method
dir(MathUtils)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'add',
#  'c']

# %% [markdown]
# ## Difference between classmethod and static method:

# %% [markdown]
# classmethod: A classmethod is a method that receives the class as its first argument, which is usually named cls. This method can modify the class state that applies across all instances of the class.
#
# staticmethod:A staticmethod is a method that does not receive any reference to either the class or its instance. It's purely a function defined inside a class.

# %%
class mathematics:
    c=10
    def __init__(self,a,b):
        self.a=a
        self.b=b
        print("default method initializer")
    @classmethod
    def add(cls,a,b):
        cls(a,b)
        print(cls.c+a+b)
(mathematics.add(3,4))
# Out:
# default method initializer
# 17

# %%
class mathematics:
    c=10
    @staticmethod
    def add(a,b):
        # print(c+a+b) error will occur as staticmethod cannot access the class attribute
        print(mathematics.c+a+b)
mathematics.add(3,4)
# Out:
# 17

# %% [markdown]
# # Accessibility
# - In python there are no keywors like public,protected or private. All attribute and methods are public by default

# %%
# PUBLIC and Private Data members
class ABC:
    def __init__(self,var1,var2):
        self.var1 = var1
        self.__var2= var2 # double underscore defines the variable as private
    def display(self):
        print("From class method var1 =",self.var1)
        print("From class method var2=",self.__var2)
    def getVar2(self):
        return self.__var2
obj = ABC(10,20)
obj.display()
print("From main module var1=",obj.var1)
#print("From main module var2=",obj.__var2)
# private member is not access aforementiontioned programming
# objectname._classname__privatevariable
print("From main module var2=",obj._ABC__var2)
print(obj.getVar2())
# Out:
# From class method var1 = 10
# From class method var2= 20
# From main module var1= 10
# From main module var2= 20
# 20

# %% [markdown]
# # del(Destructor method)

# %% [markdown]
# What is a Destructor?
# A destructor is a special method called __del__ that is invoked when an object is about to be destroyed. It is useful for releasing resources, such as closing files or network connections, before the object is removed from memory.
#
# When is __del__ Called?
# The __del__ method is called when an object is about to be destroyed, typically when it goes out of scope or is explicitly deleted using del. However, since Python uses automatic garbage collection, the exact timing of the destructor call is not guaranteed.
#
# How to Define a Destructor?
# You can define a destructor method within a class using the __del__ method.

# %%
class Demo:
    def __init__(self):
        print("Welcome")
    def __del__(self):
        print("Bye")
obj1 = Demo()
obj2 = obj1
obj3 = obj1
print("Id of obj1=",id(obj1))
print("Id of obj2=",id(obj2))
print("Id of obj3=",id(obj3))
del obj1
del obj2
del obj3 
# __del__ (Destructor)
#Automatically called when no references to the object remain.
#Prints "Bye" when del obj3 is executed.
#gc.collect()  # Forces garbage collection, ensuring __del__ runs
# Out:
# Welcome
# Id of obj1= 1153058100416
# Id of obj2= 1153058100416
# Id of obj3= 1153058100416
# Bye

# %%
import gc

class Demo:
    def __init__(self):
        print("Welcome")

    def __del__(self):
        print("Bye")

obj1 = Demo()
obj2 = obj1
obj3 = obj1

print("Id of obj1=", id(obj1))
print("Id of obj2=", id(obj2))
print("Id of obj3=", id(obj3))

del obj1
del obj2
del obj3

# Python uses automatic garbage collection, the __del__ method might not run 
# immediately when you del an object. 
# Instead, you can use gc.collect() to force garbage collection:
gc.collect()  # Forces garbage collection, ensuring __del__ runs

# %%
# Checking Reference Count
# To explicitly check how many references exist to
# the object before deletion, use sys.getrefcount():
import sys

class Demo:
    def __init__(self):
        print("Welcome")

    def __del__(self):
        print("Bye")

obj1 = Demo()
obj2 = obj1
obj3 = obj1

print("Reference count before deletion:", sys.getrefcount(obj1) - 1)  # Subtract 1 due to function argument

del obj1
del obj2
del obj3
# Out:
# Welcome
# Reference count before deletion: 3
# Bye

# %% [markdown]
# ## __new__ method(actual constructor in python)

# %% [markdown]
# - In Python, __init__ is often referred to as a constructor, but technically, it is not the actual constructor.
# - Constructor in Python
# - The actual constructor in Python is the __new__ method.
# - __new__ is called before __init__ and is responsible for creating the instance.
# - __new__ is responsible for creating a new instance of the class.
# - It is a static method that returns a new instance of the class.
# - __new__ is a special method responsible for creating a new instance of a class before __init__ initializes it. It is typically used when customizing instance creation, such as implementing singletons, immutable objects, or metaclasses.

# %% [markdown]
# The __new__ method in Python is a special method responsible for creating a new instance of a class. It is called before the __init__ method and is used when you need to control the creation of a new instance of a class.
#
# How __new__ Works:
# The __new__ method is a static method of the class, and it is responsible for returning a new instance of the class. It takes the class as its first argument, followed by any additional arguments that are passed to the class constructor.

# %%
# Syntax:
class MyClass:
    def __new__(cls, *args, **kwargs):
        # Create and return a new instance
        instance = super(MyClass, cls).__new__(cls)
        return instance

# %%
class MyClass:
    def __new__(cls, *args, **kwargs):
        print("Creating instance")
        instance = super(MyClass, cls).__new__(cls)
        return instance
    
    def __init__(self, value):
        print("Initializing instance")
        self.value = value

# Create an object
obj = MyClass(10)
# Out:
# Creating instance
# Initializing instance

# %%
class MyClass:
    def __new__(cls):
        print("Creating instance...") # calls the default object creator (object.__new__).
        instance = super().__new__(cls)  # Call object.__new__ to create instance 
        return instance  # Return the created instance

    def __init__(self):
        print("Initializing instance...")

obj = MyClass()
obj = MyClass()
# Out:
# Creating instance...
# Initializing instance...
# Creating instance...
# Initializing instance...

# %% [markdown]
# # Question: Singleton Pattern using

# %% [markdown]
# #__init__ Method (Initializer)
#     - __init__ is called after the instance is created (by __new__).
#     - It is used to initialize the attributes of the instance.
#     - It does not create the object but simply prepares it for use.

# %%
class Number:
    even =0
    def check(self,num):
        if num%2==0:
            self.even=1
    def even_odd(self,num):
        self.check(num)
        if self.even==1:
            print(num,"is even")
        else:
            print(num,"is odd")
n = Number()
n.even_odd(21)
n1 = Number()
n1.even_odd(22)
# Out:
# 21 is odd
# 22 is even

# %%
class Example:
    def __new__(cls):
        print("Inside __new__")
        instance = super().__new__(cls)
        return instance

    def __init__(self):
        print("Inside __init__")

obj = Example()

# Conclusion
# __new__ is the constructor in Python, responsible for creating the object.
# __init__ is the initializer, used for setting up instance attributes.
# Normally, you don’t need to override __new__, unless you are implementing singleton patterns or working with metaclasses.
# Out:
# Inside __new__
# Inside __init__

# %% [markdown]
# - Inheritence
# <href>https://www.youtube.com/watch?v=RSl87lqOXDE</href>

# %%
class OverloadDemo:
    def add(self,a,b):
        return(a+b)
    def add(self,a,b,c):
        return(a+b+c)
p  = OverloadDemo()
print(p.add(20,30))
print(p.add(20,3.40,40.0))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18852\1442910841.py in <module>
#       5         return(a+b+c)
#       6 p  = OverloadDemo()
# ----> 7 print(p.add(20,30))
#       8 print(p.add(20,3.40,40.0))
#
# TypeError: add() missing 1 required positional argument: 'c'

# %%
class OverloadDemo:
    def add(self,a,b):
        return(a+b)
    def add(self,a,b,c):
        return(a+b+c)
p  = OverloadDemo()
print(p.add(20,30))
print(p.add(20,3.40,40.0))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17044\1442910841.py in <module>
#       5         return(a+b+c)
#       6 p  = OverloadDemo()
# ----> 7 print(p.add(20,30))
#       8 print(p.add(20,3.40,40.0))
#
# TypeError: add() missing 1 required positional argument: 'c'

# %%
class OverloadDemo:
    def add(self,a,b,c=0):
        return(a+b+c)
   
p  = OverloadDemo()
print(p.add(20,30))
print(p.add(20,3.40,40.0))
# Out:
# 50
# 63.4

# %%
class OverloadDemo:
    def add(self,*args):
        num=0
        for num in args:
            num+=num
        return num
   
p  = OverloadDemo()
print(p.add(20,30))
print(p.add(20,3.40,40.0))
# Out:
# 60
# 80.0

# %%
class A:
    def show(self):  # 1 
        print("A show")
class B(A):
    def show(self):  #2
        print("B show")
    
   
# Case 1
'''
a  = A()
a.show()
b  = B()
b.show()
'''

# Case 2
b = B()
b.show()
# Out:
# B show

# %%
class A:
    def show(self):  # 1 
        print("A show")
class B(A):
    pass  # 1
    
b  = B()
b.show()
# Out:
# A show

# %%
class A:
    def show(self):
        print("in show")
class B:
    pass
a = A()
a.show()
# Out:
# in show

# %%
class A:
    def show(self):
        print("in show A")
class B(A):
    pass
a = A()
a.show()
# Out:
# in show A

# %%
class A:
    def show(self):
        print("in show A")
class B(A):
    pass
a = A()
a.show()
b = B()
b.show()
# Out:
# in show A
# in show A

# %%
class A:
    def show(self):
        print("in show A")
class B(A):
    def show(self):
        print("in show B")
a = A()
a.show()
b = B()
b.show()
# Out:
# in show A
# in show B

# %%
class A:
    def show(self):
        print("in show A")
class B(A):
    def show(self):
        super().show()
        # second way to print the same:
        # A.show(self)  #Not Poss
        print("in show B")
b = B()
b.show()
# Out:
# in show A
# in show B

# %%
class A:
    def __init__(self):
        self.a = 10
        self.b = 20
class B(A):
    def __init__(self):
        super().__init__()
        self.c=30
    def add(self):
        return self.a+self.b+self.c
b = B()
b.add()
# Out:
# 60

# %%
class A:
    def __init__(self):
       print("A class")
class B(A):
    def __init__(self):
        super().__init__()
        print("B class")
class C(B):
    def __init__(self):
        #super().__init__()
        print("C class")

#Case 1
#a = A()
#b = B()
c = C()
# Out:
# C class

# %%
class ABC():
    class_var=0
    def __init__(self,var):
        ABC.class_var+=1
        self.var = var
        print("the object value is:",var)
        print("the object value is:",ABC.class_var)
obj1 = ABC(10)
obj2 = ABC(20)
obj3 = ABC(30)
# Out:
# the object value is: 10
# the object value is: 1
# the object value is: 20
# the object value is: 2
# the object value is: 30
# the object value is: 3

# %%
class ABC():
    class_var=0
    def __init__(self,var):
        ABC.class_var+=1
        self.var = var
        print("the object value is:",var)
        print("the object value is:",ABC.class_var)
    def __del__(self):
        ABC.class_var-=1
        print("Object with value %d is going out of scope",self.var)
obj1 = ABC(10)
obj2 = ABC(20)
obj3 = ABC(30)
del obj1
del obj2
del obj3
# Out:
# the object value is: 10
# the object value is: 1
# the object value is: 20
# the object value is: 2
# the object value is: 30
# the object value is: 3
# Object with value %d is going out of scope 10
# Object with value %d is going out of scope 20
# Object with value %d is going out of scope 30

# %%
class ABC():
    def __init__(self,name,var):
        self.name  = name
        self.var = var
    def __repr__(self):  # string represenation
        return repr(self.var)
    def __len__(self):
        return len(self.name)
    def __cmp__(self,obj):
        return self.var-obj.var
obj  = ABC("SVNITAI",20)
print("The value stored in object is:",repr(obj))
print("The length stored in object is:",len(obj))
obj1  = ABC("SVNITIPG",30)
val= obj.__cmp__(obj1)
if val==0:
    print("Both are equal")
elif val==-1:
    print("First value is less than second")
else:
    print("Second value of less than first")
# Out:
# The value stored in object is: 20
# The length stored in object is: 7
# Second value of less than first

# %%
class Numbers:
    def __init__(self,myList):
        self.myList = myList
    def __getitem__(self,index):
        return self.myList[index]
    def __setitem__(self,index,val):
        self.myList[index] = val
NumList  = Numbers([1,2,3,4,5,6,7,8,9])
print(NumList[5])  #  Call the getmethod
NumList[3] = 100 # Call the set method
print(NumList.myList)
# Out:
# 6
# [1, 2, 3, 100, 5, 6, 7, 8, 9]

# %%
5+5
5<6
class Person:
    pass
p1  =  Person;
p2  = Person;
p1+p2
# Out:
# True

# %%
class A:
    def show(self):
        print("in show A")
class B(A):
    def show(self,a,b):
        print("in show B",(a+b))
a = A()
a.show()
b = B()
b.show(3,4)
# Out:
# in show A
# in show B 7

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def display(self):
        print("Name:",self.name)
        print("Age:",self.age)
class Teacher(Person):
    def __init__(self,name,age,exp,rec_area):
        Person.__init__(self,name,age)
        self.exp = exp
        self.rec_area = rec_area
    def displayData(self):
        Person.display(self)
        print("exp:",self.exp)
        print("rec_area:",self.rec_area)
T = Teacher("Amit",34,10,"DL")
T.displayData()
# Out:
# Name: Amit
# Age: 34
# exp: 10
# rec_area: DL

# %%
class Greather:
    def __init__(self,r):
        self.real  = r
       
    def __gt__(self,other):
        if self.real> other.real:
            return True
        else:
           return False
c1 = Greather(3)
c2 = Greather(4)
if c1>c2:             # c1.__gt__(c2)
    print("C1 is greather")
else:
    print("C2 is greather")
# Out:
# C2 is greather

# %%
class ComplexNumber:
    def __init__(self,r,i):
        self.real  = r
        self.img =i
    def __add__(self,other):
        self.real+ other.real
        self.img + other.img
        return f"{self.real+other.real}+{self.img+other.img}i"
        #return self.real,self.img
c1 = ComplexNumber(3,4)
c2 = ComplexNumber(4,5)
print(c1+c2)  #  c1.__add__(c2)

# %%
class A:
    def show():
        pass
class B(A):
    def show(self):
        print("B show")
#a = A()
#a.show()
b = B()
b.show()
# Out:
# B show

# %%
from abc import abstractmethod
class A: #Abstract class
    @abstractmethod
    def show(self):
        pass
   
class B(A):
    def show(self):
        print("B class")

#a = A()
#a.show()
b = B()
b.show()
# Out:
# B class

# %%
from abc import ABC, abstractmethod

# Define an abstract class
class Animal(ABC):
    
    def __init__(self):
        print("Abstra")
    @abstractmethod
    def sound(self):
        pass  # This is an abstract method, no implementation here.

# Concrete subclass of Animal
class Dog(Animal):
    
    def sound(self):
        return "Bark"  # Providing the implementation of the abstract method

#a  = Animal()  #  Abstract class is not possible
# Create an instance of Dog
dog = Dog()
print(dog.sound())  # Output: Bark
# Out:
# Abstra
# Bark

# %% [markdown]
# # Code Explanation:
#
# - Abstract Base Class: Animal is an abstract class that inherits from ABC (Abstract Base Class). This class cannot be instantiated directly because it contains an abstract method sound(). The @abstractmethod decorator is used to mark sound() as an abstract method. This means any subclass must implement this method to be instantiated.
# - Concrete Subclass: Dog is a subclass of Animal that provides an implementation for the sound() method. This allows the Dog class to be instantiated and used.
# - Instantiation: We create an instance of Dog and call the sound() method, which returns “Bark”.

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def display(self):
        print("Name ",self.name)
        print("Age ",self.age)
class Student(Person):
    def __init__(self,name,age,bcode,marks):
        Person.__init__(self,name,age)
        self.bcode = bcode
        self.marks= marks
    def displayData(self):
        Person.display(self)
        print("Student Branch Code",self.bcode)
        print("Student Branch Marks",self.marks)

class Teacher(Person):
    def __init__(self,name,age,dept,subject):
        Person.__init__(self,name,age)
        self.dept = dept
        self.subject= subject
    def displayData(self):
        Person.display(self)
        print("Teacher Department",self.dept)
        print("Teacher subject",self.subject)

s  =  Student("Amit",34,123,78)
s.displayData()
t  =  Teacher("Ram",34,"AI","CPP")
t.displayData()
'''
p  = Person("Amit",34)
p.display()
s  =  Student(231,76)
s.displayData()
'''
# Out:
# Name  Amit
# Age  34
# Student Branch Code 123
# Student Branch Marks 78
# Name  Ram
# Age  34
# Teacher Department AI
# Teacher subject CPP
# '\np  = Person("Amit",34)\np.display()\ns  =  Student(231,76)\ns.displayData()\n'

# %% [markdown]
# - In Python, class, abstract class, and interface are concepts used to structure and organize code. However, Python does not have a built-in interface keyword like some other languages (e.g., Java). Instead, interfaces are mimicked using abstract classes. Here's a detailed explanation of the differences:
# i) Class
# * A class is a blueprint for creating objects (instances).
# * It can contain attributes (variables) and methods (functions).
# * Classes can be instantiated directly.

# %%
class Dog:
    def __init__(self, name):
        self.name = name

    def bark(self):
        return "Woof!"

my_dog = Dog("Buddy")
print(my_dog.bark())  # Output: Woof!
# Out:
# Woof!

# %% [markdown]
# ii) Abstract Class
# * An abstract class is a class that cannot be instantiated directly. It is meant to be a base class for other classes.
# * It can contain both concrete methods (with implementation) and abstract methods (without implementation).
# * Abstract methods must be implemented by any subclass that inherits from the abstract class.
# * Abstract classes are created using the ABC module and the @abstractmethod decorator.

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def make_sound(self):
        pass

    def sleep(self):
        return "Sleeping"

class Dog(Animal):
    def make_sound(self):
        return "Woof!"

my_dog = Dog()
print(my_dog.make_sound())  # Output: Woof!
print(my_dog.sleep())       # Output: Sleeping
# Out:
# Woof!
# Sleeping

# %% [markdown]
#  iii) Interface
# * An interface is a contract that defines a set of methods that a class must implement.
# * Python does not have a built-in interface keyword, but interfaces can be mimicked using abstract classes with only abstract methods.
# * Interfaces are used to enforce a specific structure on classes that implement them.

# %%
from abc import ABC, abstractmethod

class Swimmable(ABC):
    @abstractmethod
    def swim(self):
        pass

class Fish(Swimmable):
    def swim(self):
        return "Fish is swimming"

class Boat(Swimmable):
    def swim(self):
        return "Boat is floating"

fish = Fish()
boat = Boat()
print(fish.swim())  # Output: Fish is swimming
print(boat.swim())   # Output: Boat is floating
# Out:
# Fish is swimming
# Boat is floating

# %%
from abc import ABC, abstractmethod

# Interface-like behavior using an abstract class
class Animal(ABC):
    @abstractmethod
    def make_sound(self):
        pass

    @abstractmethod
    def move(self):
        pass

# Abstract class
class Bird(Animal):
    @abstractmethod
    def fly(self):
        pass

# Concrete class implementing the abstract class and interface
class Sparrow(Bird):
    def make_sound(self):
        return "Chirp Chirp"

    def move(self):
        return "Flying and hopping"

    def fly(self):
        return "Sparrow is flying high"

# Another concrete class
class Dog(Animal):
    def make_sound(self):
        return "Woof Woof"

    def move(self):
        return "Running on the ground"

# Main program
if __name__ == "__main__":
    sparrow = Sparrow()
    dog = Dog()

    # Using Sparrow object
    print("Sparrow:")
    print(sparrow.make_sound())
    print(sparrow.move())
    print(sparrow.fly())

    # Using Dog object
    print("\nDog:")
    print(dog.make_sound())
    print(dog.move())
# Out:
# Sparrow:
# Chirp Chirp
# Flying and hopping
# Sparrow is flying high
#
# Dog:
# Woof Woof
# Running on the ground
